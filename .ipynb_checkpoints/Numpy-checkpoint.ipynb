# %%
import numpy as np

# %%
my_arr = np.arange(1_000_000) ##O numpy é muito mais rápido

# %%
my_list = list(range(1_000_000))

# %%
# %timeit my_arr2 = my_arr *2
# Out:
# 872 μs ± 32.7 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit my_list2 = my_list * 2
# Out:
# 11.1 ms ± 67 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)
