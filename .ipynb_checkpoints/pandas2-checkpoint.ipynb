# %%
import numpy as np

# %%
import pandas as pd

# %%
labels = ['a', 'b', 'c']
my_data = [10, 20, 30]
arr = np.array(my_data)
d = {'a':10, 'b':20, 'c':30}

# %%
pd.Series(data = my_data)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(data=my_data,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
ser1 = pd.Series([1,2,3,4],['USA','Germany','USSR','Japan']) ##O primeiro seria o index e o segundo os valores

# %%
ser1
# Out:
# USA        1
# Germany    2
# USSR       3
# Japan      4
# dtype: int64

# %%
ser1['USA']
# Out:
# np.int64(1)

# %%
ser2 = pd.Series([1,2,3,4],['USA','Germany','USSR','Japan'])## Se existir uma correspondencia entre os index ele somará se não, null

# %%
ser2+ser1
# Out:
# USA        2
# Germany    4
# USSR       6
# Japan      8
# dtype: int64

# %%
##DataFrames

# %%
df = pd.DataFrame(np.random.randn(5,4),['A','B','C','D','E'],['W','X','Y','Z'])

# %%
df
# Out:
#           W         X         Y         Z
# A -0.158641 -0.068974  0.467821  0.002384
# B -0.336666 -1.564364  0.208535  0.734320
# C  0.930209 -0.833984  0.830042 -1.995710
# D -0.671856  1.122351 -0.075790 -1.183756
# E -1.350930 -1.255814 -0.011393 -0.815810

# %%
df['W'] ##Vai pegar a coluna de w
# Out:
# A   -0.158641
# B   -0.336666
# C    0.930209
# D   -0.671856
# E   -1.350930
# Name: W, dtype: float64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.W ##Mesma coisa que df['W']
# Out:
# A   -0.158641
# B   -0.336666
# C    0.930209
# D   -0.671856
# E   -1.350930
# Name: W, dtype: float64

# %%
df['new'] = df['W'] + df['Y'] ## Criacao de uma nova coluna com o somatório das duas anteriores

# %%
df
# Out:
#           W         X         Y         Z       new
# A -0.158641 -0.068974  0.467821  0.002384  0.309180
# B -0.336666 -1.564364  0.208535  0.734320 -0.128131
# C  0.930209 -0.833984  0.830042 -1.995710  1.760251
# D -0.671856  1.122351 -0.075790 -1.183756 -0.747646
# E -1.350930 -1.255814 -0.011393 -0.815810 -1.362322

# %%
df.drop('new',axis=1, inplace=True)## apagar a coluna da tabela, nesse caso precisamos passar o axis = 1 e o nome,e o inplace é a confirmacao que devemos apagar

# %%
df[['Z','X']]
# Out:
#           Z         X
# A  0.002384 -0.068974
# B  0.734320 -1.564364
# C -1.995710 -0.833984
# D -1.183756  1.122351
# E -0.815810 -1.255814

# %%
df.loc['C'] ## Pegar a linha A como referência
# Out:
# W    0.930209
# X   -0.833984
# Y    0.830042
# Z   -1.995710
# Name: C, dtype: float64

# %%
df.iloc[2] ##iloc passa o indice da linha
# Out:
# W    0.930209
# X   -0.833984
# Y    0.830042
# Z   -1.995710
# Name: C, dtype: float64

# %%
df.loc['B','Y'] ## O primeiro parâmetro indica a linha e a segunda a coluna
# Out:
# np.float64(0.20853503614978663)

# %%
df.loc[['A', 'B'], ['W', 'Y']]
# Out:
#           W         Y
# A -0.158641  0.467821
# B -0.336666  0.208535

# %%
booldf = df>0

# %%
booldf
# Out:
#        W      X      Y      Z
# A  False  False   True   True
# B  False  False   True   True
# C   True  False   True  False
# D  False   True  False  False
# E  False  False  False  False

# %%
df[booldf]
# Out:
#           W         X         Y         Z
# A       NaN       NaN  0.467821  0.002384
# B       NaN       NaN  0.208535  0.734320
# C  0.930209       NaN  0.830042       NaN
# D       NaN  1.122351       NaN       NaN
# E       NaN       NaN       NaN       NaN

# %%
df['W'] > 0
# Out:
# A    False
# B    False
# C     True
# D    False
# E    False
# Name: W, dtype: bool

# %%
resultdf = df[df['W']>0]["W"] ##Retornará os valores e não o boolean

# %%
resultdf
# Out:
# C    0.930209
# Name: W, dtype: float64

# %%
boolser = df["W"]>0 ## Pandas compara cada valor na coluna w com 0
result = df[boolser] ## Usamos essa máscara para filtrar as linhas, e retornar valores
mycols = ['Y','X']##
result[mycols]
# Out:
#           Y         X
# C  0.830042 -0.833984

# %%
df
# Out:
#           W         X         Y         Z
# A -0.158641 -0.068974  0.467821  0.002384
# B -0.336666 -1.564364  0.208535  0.734320
# C  0.930209 -0.833984  0.830042 -1.995710
# D -0.671856  1.122351 -0.075790 -1.183756
# E -1.350930 -1.255814 -0.011393 -0.815810

# %%
df[(df['W']> 0) | (df['Y']> 1)]
# Out:
#           W         X         Y        Z
# C  0.930209 -0.833984  0.830042 -1.99571

# %%
df
# Out:
#           W         X         Y         Z
# A -0.158641 -0.068974  0.467821  0.002384
# B -0.336666 -1.564364  0.208535  0.734320
# C  0.930209 -0.833984  0.830042 -1.995710
# D -0.671856  1.122351 -0.075790 -1.183756
# E -1.350930 -1.255814 -0.011393 -0.815810

# %%
newind = 'CA NY WY OR CO'.split() ## Criacao de um novo index

# %%
df['States'] = newind

# %%
df
# Out:
#           W         X         Y         Z States
# A -0.158641 -0.068974  0.467821  0.002384     CA
# B -0.336666 -1.564364  0.208535  0.734320     NY
# C  0.930209 -0.833984  0.830042 -1.995710     WY
# D -0.671856  1.122351 -0.075790 -1.183756     OR
# E -1.350930 -1.255814 -0.011393 -0.815810     CO

# %%
df.set_index('States') ## Criacao de estados no index
# Out:
#                W         X         Y         Z
# States
# CA     -0.158641 -0.068974  0.467821  0.002384
# NY     -0.336666 -1.564364  0.208535  0.734320
# WY      0.930209 -0.833984  0.830042 -1.995710
# OR     -0.671856  1.122351 -0.075790 -1.183756
# CO     -1.350930 -1.255814 -0.011393 -0.815810

# %%
outside = [ 'G1','G1','G1','G2','G2','G2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)

# %%
df = pd.DataFrame(np.random.randn(6,2),hier_index,['A', 'B'])

# %%
df
# Out:
#              A         B
# G1 1 -2.549104  0.523426
#    2  0.778020 -0.742522
#    3  0.158621 -0.968187
# G2 1  2.265176 -0.318779
#    2  1.290790  0.602098
#    3 -1.002518 -1.464448

# %%
df.index.names = ['Groups','Num']

# %%
df
# Out:
#                    A         B
# Groups Num
# G1     1   -2.549104  0.523426
#        2    0.778020 -0.742522
#        3    0.158621 -0.968187
# G2     1    2.265176 -0.318779
#        2    1.290790  0.602098
#        3   -1.002518 -1.464448

# %%
df.loc['G2'].loc[2]
# Out:
# A    1.290790
# B    0.602098
# Name: 2, dtype: float64

# %%
df.loc['G1'].loc[1]['B']
# Out:
# np.float64(0.5234256052514872)

# %%
df.xs(1, level="Num")
# Out:
#                A         B
# Groups
# G1     -2.549104  0.523426
# G2      2.265176 -0.318779

# %%
d = {'A': [1,2,np.nan],'B':[5,np.nan,np.nan],'C':[1,2,3]}

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna() ## Vai dropar todos os valores com NAN
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(thresh=2) ## Removerá NAN maior ou igual a 2
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2

# %%
df.fillna(value='FILL VALUE') ## Preenche os valores de NAN com essa string
# Out:
#             A           B  C
# 0         1.0         5.0  1
# 1         2.0  FILL VALUE  2
# 2  FILL VALUE  FILL VALUE  3

# %%
data = {'Company': ['GOOG', 'GOOG', 'MSFT', 'MSFT', 'FB', 'FB'],
'Person': ['Sam', 'Charlie', 'Amy', 'Vanessa', 'Carl', 'Sarah'],
'Sales': [200, 120, 340,124,243,350]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %%
byComp =  df.groupby('Company')

# %%
byComp.mean(numeric_only=True) ## Retorna a média
# Out:
#          Sales
# Company
# FB       296.5
# GOOG     160.0
# MSFT     232.0

# %%
byComp.sum().loc['FB']## Retorna a soma da linha FB
# Out:
# Person    CarlSarah
# Sales           593
# Name: FB, dtype: object

# %%
df.groupby('Company').describe() ## Retorna estatisticas da tabela
# Out:
#         Sales
#         count   mean         std    min     25%    50%     75%    max
# Company
# FB        2.0  296.5   75.660426  243.0  269.75  296.5  323.25  350.0
# GOOG      2.0  160.0   56.568542  120.0  140.00  160.0  180.00  200.0
# MSFT      2.0  232.0  152.735065  124.0  178.00  232.0  286.00  340.0

# %%
df1 = pd.DataFrame({'A':['A0','A1','A2','A3'],
                   'B':['B0','B1','B2','B3'],
                   'C':['C0','C1','C2','C3'],
                   'D':['D0','D1','D2','D3']},
                   index=[0, 1, 2, 3])

# %%
df2 = pd.DataFrame({'A':['A4','A5','A6','A7'],
                   'B':['B4','B5','B6','B7'],
                   'C':['C4','C5','C6','C7'],
                   'D':['D4','D5','D6','D7']},
                   index=[4, 5, 6, 7])

# %%
df3 = pd.DataFrame({'A':['A8','A9','A10','A11'],
                   'B':['B8','B9','B10','B11'],
                   'C':['C8','C9','C10','C11'],
                   'D':['D8','D9','D10','D11']},
                   index=[8,9,10,11])

# %%
pd.concat([df1,df2,df3]) ##Concatenação entre os dataFrames criados
# Out:
#       A    B    C    D
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
left = pd.DataFrame({'Key1':['Kdf1 = pd.DataFrame({'A':['A0','A1','A2','A3'],
                   'B':['B0','B1','B2','B3'],
                   'C':['C0','C1','C2','C3'],
                   'D':['D0','D1','D2','D3']},
                   index=[4, 5, 6, 7])'']})
