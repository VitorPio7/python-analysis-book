# %%
import numpy as np

# %%
import pandas as pd

# %%
from pandas import Series, DataFrame

# %%
##Introduction

# %%
obj = pd.Series([4,7,-5,3]) ##dimenciona um array com uma dimensão

# %%
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
obj.array
# Out:
# <NumpyExtensionArray>
# [4, 7, -5, 3]
# Length: 4, dtype: int64

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
obj2 = pd.Series([4, 7, -5, 3], index=["d","b","a","c"]) ##Podemos incluir index custom para o nosso objeto

# %%
obj2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
obj2.array
# Out:
# <NumpyExtensionArray>
# [4, 7, -5, 3]
# Length: 4, dtype: int64

# %%
obj2.index
# Out:
# Index(['d', 'b', 'a', 'c'], dtype='object')

# %%
obj2["a"]
# Out:
# np.int64(-5)

# %%
obj2["c"] = 6

# %%
obj2
# Out:
# d    4
# b    7
# a   -5
# c    6
# dtype: int64

# %%
obj2[obj2>0] ## Filtragen que vai filtrar um objeto maior do que 0
# Out:
# d    4
# b    7
# c    6
# dtype: int64

# %%
obj2*2
# Out:
# d     8
# b    14
# a   -10
# c    12
# dtype: int64

# %%
np.exp(obj2) ##Podemos utilizar a biblioteca nupy para trabalhar com o pandas
# Out:
# d      54.598150
# b    1096.633158
# a       0.006738
# c     403.428793
# dtype: float64

# %%
"b" in obj2
# Out:
# True

# %%
"f" in obj2
# Out:
# False

# %%
sdata = {"Ohio":35000,"Texas":71000,"Oregon":16000, "Utah": 5000} ## Podemos criar um pandas object através de um dictionary

# %%
obj3 = pd.Series(sdata)

# %%
obj3
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
obj3.to_dict() ##Podemos converter de volta para o dicionario
# Out:
# {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}

# %%
states = ["California","Ohio","Oregon","Texas"]

# %%
obj4 = pd.Series(sdata, index=states)

# %%
obj4
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %%
pd.isna(obj4) ## isna retorna boolean para dados que estiverem faltando
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %%
obj3+obj4
# Out:
# California         NaN
# Ohio           70000.0
# Oregon         32000.0
# Texas         142000.0
# Utah               NaN
# dtype: float64

# %%
## DATAFRAMES, representa uma tabela retangular de dados e contem uma ordem,

# %%
##Ele é 2d, ao contrário do Series que é 1d

# %%
data = {
    "state":["Ohio","Ohio","Ohio","Nevada","Nevada","Nevada",],
    "year":[2000, 2001, 2002, 2001, 2002, 2003],
    "pop":[1.5, 1.7, 3.6, 2.4, 2.9, 3.2]
}

# %%
data
# Out:
# {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
#  'year': [2000, 2001, 2002, 2001, 2002, 2003],
#  'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}

# %%
frame = pd.DataFrame(data)

# %%
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
frame.head() ##Vai demonstrar apenas os primeiros cinco resultados da tabela
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9

# %%
frame.tail()## Retorna os ultimos 5 resultados
# Out:
#     state  year  pop
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
pd.DataFrame(data, columns=["year","state","pop"]) ## podemos organizar as colunas passando esses parâmetros
# Out:
#    year   state  pop
# 0  2000    Ohio  1.5
# 1  2001    Ohio  1.7
# 2  2002    Ohio  3.6
# 3  2001  Nevada  2.4
# 4  2002  Nevada  2.9
# 5  2003  Nevada  3.2

# %%
frame2 = pd.DataFrame(data, columns=["year","state","pop","debt"])

# %%
frame2
# Out:
#    year   state  pop debt
# 0  2000    Ohio  1.5  NaN
# 1  2001    Ohio  1.7  NaN
# 2  2002    Ohio  3.6  NaN
# 3  2001  Nevada  2.4  NaN
# 4  2002  Nevada  2.9  NaN
# 5  2003  Nevada  3.2  NaN

# %%
frame2["state"]
# Out:
# 0      Ohio
# 1      Ohio
# 2      Ohio
# 3    Nevada
# 4    Nevada
# 5    Nevada
# Name: state, dtype: object

# %%
frame2.year
# Out:
# 0    2000
# 1    2001
# 2    2002
# 3    2001
# 4    2002
# 5    2003
# Name: year, dtype: int64

# %%
frame2.loc[1] ## Retorna a primeira linha
# Out:
# year     2001
# state    Ohio
# pop       1.7
# debt      NaN
# Name: 1, dtype: object

# %%
frame.iloc[2] ## Retorna a segunda linha
# Out:
# state    Ohio
# year     2002
# pop       3.6
# Name: 2, dtype: object

# %%
frame2["debt"] = 16.5 ## Vai destinar a coluna com esses valores

# %%
frame2
# Out:
#    year   state  pop  debt
# 0  2000    Ohio  1.5  16.5
# 1  2001    Ohio  1.7  16.5
# 2  2002    Ohio  3.6  16.5
# 3  2001  Nevada  2.4  16.5
# 4  2002  Nevada  2.9  16.5
# 5  2003  Nevada  3.2  16.5

# %%
frame2["debt"] = np.arange(6.) ##sorteia seis na coluna debt

# %%
frame2
# Out:
#    year   state  pop  debt
# 0  2000    Ohio  1.5   0.0
# 1  2001    Ohio  1.7   1.0
# 2  2002    Ohio  3.6   2.0
# 3  2001  Nevada  2.4   3.0
# 4  2002  Nevada  2.9   4.0
# 5  2003  Nevada  3.2   5.0
