# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
x = np.linspace(0,5,11)

# %%
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')
plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %%
## OO
## É mais personalizável do que o anterior, mas chegamos nos mesmos resultados
fig = plt.figure()

axes = fig.add_axes([0.1,0.1,0.8,0.8])

axes.plot(x,y)
axes.set_xlabel('X Label')
axes.set_ylabel('Y Label')
axes.set_title('Set Title')
# Out:
# Text(0.5, 1.0, 'Set Title')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes1.plot(x,y)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2) ##Não precisamos adicionar o axis, aqui ele coloca automaticamente

##for current_ax in axes:
##  current_ax.plot(x,y)

axes[0].plot(x,y)
axes[0].set_title('First Plot')

axes[1].plot(y,x)
axes[1].set_title('Second Plot')
# Out:
# Text(0.5, 1.0, 'Second Plot')

# %%
##Figure and DPI

# %%
fig = plt.figure(figsize=(3,2),dpi=100)

# %%
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(8,2))
plt.tight_layout() ## coloca um espacamento entre as tabelas

# %%
fig.savefig('my_picture.png') ## vai salvar o gráfico em um arquivo

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x, x,label='X Squared') ## label vai implementar a consulta da tabela
ax.plot(x, x**2,label='X Cubed')
ax.set_title('Title')
ax.set_ylabel('Y')
ax.set_xlabel('X')
ax.legend(loc=0)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, y, color="purple",linewidth=1, alpha=1, linestyle='-', marker='o', markersize=8,
       markerfacecolor="yellow",markeredgewidth=3,markeredgecolor='green') 
## linewidth diz sobre a espessura, alpha diz sobre a opacidade
ax.set_xlim([0,1]) ##Permite traçar ou isolar os dados
ax.set_ylim([0,2]) ##Permite isolar no eixo y
# Out:
# (0.0, 2.0)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,4)) ## 1 linha e duas colunas do tamanho 10x4
axes[0].plot(x,x**2,x,np.exp(x)) ## Incersão dos dados na tabela
axes[0].set_title("Normal scale") ## coloca o título do gráfico
axes[1].plot(x, x**2,x,np.exp(x)) ## coloca info no segundo gráfico
axes[1].set_yscale("log") ## muda o tipo da escala de y
axes[1].set_title('Logarithmic scale(y)')
# Out:
# Text(0.5, 1.0, 'Logarithmic scale(y)')

# %%
fig, ax = plt.subplots(figsize=(10,4)) ## Criação de gráfico
ax.plot(x,x**2,x,x**3,lw=2)

ax.set_xticks([1, 2, 3, 4, 5]) ## Customização do nosso eixo x
ax.set_xticklabels([r'$\alpha$', r'$\beta$', r'$\gamma$', r'$\delta$', r'$\epsilon$'], fontsize=18)

yticks = [0, 50, 100, 150] ## Eixo y customizado
ax.set_yticks(yticks)

# %%
fig, ax = plt.subplots(1, 1)

ax.plot(x, x**2, x, np.exp(x))
ax.set_title("scientific notation")

ax.set_yticks([0, 50, 100, 150])

from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,1))
ax.yaxis.set_major_formatter(formatter)

# %%
plt.rcParams['xtick.major.pad'] = 5
plt.rcParams['ytick.major.pad'] = 5

fig, ax = plt.subplots(1,1)

ax.plot(x, x**2,x,np.exp(x))
ax.set_yticks([0, 50, 100, 150])

ax.set_title("label and axis spacing")
ax.yaxis.labelpad = 5
ax.yaxis.labelpad = 5

ax.set_xlabel("x")
ax.set_ylabel("y")

fig.subplots_adjust(left=0.15, right=.95, bottom=.1,top=.95) ## Ajusta o tamanho do gráfico
ax.grid(color='gray',alpha=0.5,linestyle='dashed',linewidth=0.5) ##Ajusta e configura o grid
ax.spines['bottom'].set_color('red') ## Altera a cor da linha abaixo

ax2 = ax.twinx()
ax2.plot(x, x**3, lw=2, color="blue") ##Criamos uma reta irmã com essas configuracões
ax2.set_ylabel(r"volume $(m³)$")
for label in ax2.get_yticklabels():
    label.set_color("red")

# %%
fig, ax = plt.subplots()

ax.spines['right'].set_color('black')
ax.spines['left'].set_color('red')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

xx = np.linspace(-0.75,1.,100)
ax.plot(xx,xx**3)

# %%
n = np.array([0,1,2,3,4,5])

# %%
fig, axes = plt.subplots(1,4,figsize=(12,3))
axes[0].scatter(xx,xx+0.25*np.random.randn(len(xx)))
axes[0].set_title('scatter')

axes[1].step(n,n**2,lw=2)
axes[1].set_title("step")

axes[2].bar(n,n**2,align="center",width=0.5,alpha=0.5)
axes[2].set_title("bar")

axes[3].fill_between(x, x**2, x**3, color="green",alpha=0.5)
axes[3].set_title("fill_between")
# Out:
# Text(0.5, 1.0, 'fill_between')

# %%
fig, ax = plt.subplots()

ax.plot(xx,xx**2,xx,xx**3)

ax.text(0.15,0.2,r"$y=x²$",fontsize=15, color="blue")
ax.text(0.65,0.1,r"$y=x^3$",fontsize=15, color="green")
# Out:
# Text(0.65, 0.1, '$y=x^3$')

# %%
fig, ax = plt.subplots(2,3)
fig.tight_layout()

# %%
fig = plt.figure()
ax1 = plt.subplot2grid((3,3),(0,0),colspan=3)
ax2 = plt.subplot2grid((3,3),(1,0),colspan=2)
ax3 = plt.subplot2grid((3,3),(1,2),rowspan=2)
ax4 = plt.subplot2grid((3,3),(2,0))
ax5 = plt.subplot2grid((3,3),(2,0))
fig.tight_layout()

# %%
import matplotlib.gridspec as gridspec

# %%
fig = plt.figure()

gs = gridspec.GridSpec(2,3,height_ratios=[2,1],width_ratios=[1,2,1])
for g in gs:
    ax = fig.add_subplot(g)
fig.tight_layout()

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

# %%
alpha = 0.7
phi_ext = 2 * np.pi * 0.5

def flux_qubut_potential(phi_m,phi_p):
    return 2 + alpha - 2 * np.cos(phi_p) * np.cos(phi_m) - alpha * np.cos(phi_ext - 2*phi_p)
    
z = flux_qubut_potential(x,y).T

fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(1, 1, 1, projection='3d')

p = ax.plot_wireframe(x, y, z, rstride=4, cstride=4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[76], line 13
#       9 fig = plt.figure(figsize=(8,6))
#      11 ax = fig.add_subplot(1, 1, 1, projection='3d')
# ---> 13 p = ax.plot_wireframe(x, y, z, rstride=4, cstride=4)
#
# File ~/Documents/pythonBook/python-analysis-book/jupyter_env/lib/python3.10/site-packages/mpl_toolkits/mplot3d/axes3d.py:2370, in Axes3D.plot_wireframe(self, X, Y, Z, axlim_clip, **kwargs)
#    2368 had_data = self.has_data()
#    2369 if Z.ndim != 2:
# -> 2370     raise ValueError("Argument Z must be 2-dimensional.")
#    2371 # FIXME: Support masked arrays
#    2372 X, Y, Z = np.broadcast_arrays(X, Y, Z)
#
# ValueError: Argument Z must be 2-dimensional.
